# %% [markdown]
# <a href="https://colab.research.google.com/github/doperjerr/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ณัฐธิดา จันทโสภา

# %%
print( '673020044-1' )
# Out:
# 673020044-1
